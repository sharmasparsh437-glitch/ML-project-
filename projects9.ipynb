# %% [markdown]
# ###9- iPhone User Comparison (2018 vs. 2026)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set a random seed for reproducibility
np.random.seed(42)

# Generate dummy data for iPhone users (in millions)
# Assuming an increase in iPhone users over time
iphone_users_2018 = np.random.randint(500, 700) # e.g., 500-700 million in 2018
iphone_users_2026 = np.random.randint(900, 1200) # e.g., 900-1200 million in 2026

# Create a DataFrame for comparison
iphone_data = pd.DataFrame({
    'Year': [2018, 2026],
    'iPhone_Users_Millions': [iphone_users_2018, iphone_users_2026]
})

print("Generated iPhone User Data (Millions):")
display(iphone_data)
# Out:
# Generated iPhone User Data (Millions):
#    Year  iPhone_Users_Millions
# 0  2018                    602
# 1  2026                   1170

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Sales_Units_Millions', data=sales_df, marker='o', color='forestgreen', linewidth=2.5)
plt.title('Sales Trend from sales_df (2016-2026)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Sales (Millions of Units)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(sales_df['Year'], rotation=45)
plt.tight_layout()
plt.show()
